# %%
pip list
# Out:
# Package                            Version          Note: you may need to restart the kernel to use updated packages.
# ---------------------------------- -----------------
# absl-py                            0.9.0
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 1.9.12
# anaconda-project                   0.8.3
# argh                               0.26.2
# asn1crypto                         1.3.0
# astor                              0.8.1
# astroid                            2.3.3
# astropy                            4.0.1.post1
# atomicwrites                       1.3.0
# attrs                              19.3.0
# autopep8                           1.4.4
# Babel                              2.8.0
# backcall                           0.1.0
# backports.functools-lru-cache      1.6.1
# backports.os                       0.1.1
# backports.shutil-get-terminal-size 1.0.0
#
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# basemap                            1.2.0
# bcrypt                             3.1.7
# beautifulsoup4                     4.6.0
# bitarray                           1.2.1
# bkcharts                           0.2
# bleach                             3.1.0
# bokeh                              2.0.1
# boto                               2.49.0
# Bottleneck                         1.3.2
# branca                             0.4.1
# cachetools                         4.0.0
# certifi                            2020.12.5
# cffi                               1.14.0
# chardet                            3.0.4
# click                              7.1.1
# cloudpickle                        1.3.0
# clyent                             1.2.2
# cmdstanpy                          0.4.0
# colorama                           0.4.3
# comtypes                           1.1.7
# conda                              4.9.2
# conda-build                        3.18.11
# conda-package-handling             1.6.0
# conda-verify                       3.4.2
# configparser                       5.0.2
# contextlib2                        0.6.0.post1
# convertdate                        2.2.0
# crayons                            0.4.0
# cryptography                       2.8
# cycler                             0.10.0
# Cython                             0.29.15
# cytoolz                            0.10.1
# dask                               2.14.0
# decorator                          4.4.2
# defusedxml                         0.6.0
# descartes                          1.1.0
# diff-match-patch                   20181111
# distributed                        2.14.0
# docutils                           0.16
# entrypoints                        0.3
# ephem                              3.7.7.0
# et-xmlfile                         1.0.1
# fastcache                          1.1.0
# fbprophet                          0.6
# filelock                           3.0.12
# flake8                             3.7.9
# flashtext                          2.7
# Flask                              1.1.1
# folium                             0.11.0
# fsspec                             0.7.1
# future                             0.18.2
# gast                               0.2.2
# geocoder                           1.38.1
# gevent                             1.4.0
# glob2                              0.7
# google-api-core                    1.23.0
# google-api-python-client           1.12.8
# google-auth                        1.23.0
# google-auth-httplib2               0.0.4
# google-auth-oauthlib               0.4.1
# google-pasta                       0.2.0
# googleapis-common-protos           1.52.0
# googlemaps                         4.2.0
# greenlet                           0.4.15
# grpcio                             1.28.1
# h5py                               2.10.0
# haversine                          2.2.0
# HeapDict                           1.0.1
# holidays                           0.10.1
# html5lib                           1.0.1
# httplib2                           0.18.1
# hyperopt                           0.2.5
# hypothesis                         5.5.4
# idna                               2.9
# imageio                            2.8.0
# imagesize                          1.2.0
# imbalanced-learn                   0.7.0
# imblearn                           0.0
# importlib-metadata                 1.5.0
# intervaltree                       3.0.2
# ipykernel                          5.1.4
# ipynb-py-convert                   0.4.6
# ipython                            7.13.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.5.1
# isort                              4.3.21
# itsdangerous                       1.1.0
# jdcal                              1.4.1
# jedi                               0.15.2
# Jinja2                             2.11.1
# joblib                             0.14.1
# JPype1                             1.3.0
# json5                              0.9.4
# jsonschema                         3.2.0
# jupyter                            1.0.0
# jupyter-client                     6.1.2
# jupyter-console                    6.1.0
# jupyter-core                       4.6.3
# jupyterlab                         1.2.6
# jupyterlab-server                  1.1.0
# Keras                              2.3.1
# Keras-Applications                 1.0.8
# Keras-Preprocessing                1.1.0
# keyring                            21.1.1
# kiwisolver                         1.1.0
# konlpy                             0.5.2
# lazy-object-proxy                  1.4.3
# libarchive-c                       2.8
# lightgbm                           2.3.1
# llvmlite                           0.31.0
# locket                             0.2.0
# LunarCalendar                      0.0.9
# lxml                               4.5.0
# Markdown                           3.2.1
# MarkupSafe                         1.1.1
# matplotlib                         3.1.3
# mccabe                             0.6.1
# menuinst                           1.4.16
# mistune                            0.8.4
# mizani                             0.7.2
# mkl-fft                            1.0.15
# mkl-random                         1.1.0
# mkl-service                        2.3.0
# mock                               4.0.1
# more-itertools                     8.2.0
# mpmath                             1.1.0
# msgpack                            1.0.0
# multipledispatch                   0.6.0
# navigator-updater                  0.2.1
# nbconvert                          5.6.1
# nbformat                           5.0.4
# networkx                           2.4
# nltk                               3.4.5
# nose                               1.3.7
# notebook                           6.0.3
# numba                              0.48.0
# numexpr                            2.7.1
# numpy                              1.18.1
# numpydoc                           0.9.2
# oauth2client                       4.1.3
# oauthlib                           3.1.0
# olefile                            0.46
# opencv-python                      4.5.2.52
# openpyxl                           3.0.3
# opt-einsum                         3.2.0
# packaging                          20.3
# palettable                         3.3.0
# pandas                             0.23.4
# pandocfilters                      1.4.2
# paramiko                           2.7.1
# parso                              0.5.2
# partd                              1.1.0
# path                               13.1.0
# pathlib2                           2.3.5
# pathtools                          0.1.2
# patsy                              0.5.1
# pep8                               1.7.1
# pexpect                            4.8.0
# pickleshare                        0.7.5
# Pillow                             7.0.0
# pip                                20.0.2
# pkginfo                            1.5.0.1
# plotnine                           0.5.0
# pluggy                             0.13.1
# ply                                3.11
# prometheus-client                  0.7.1
# prompt-toolkit                     3.0.4
# prophet                            0.1.1
# protobuf                           3.14.0
# psutil                             5.7.0
# py                                 1.8.1
# pyasn1                             0.4.8
# pyasn1-modules                     0.2.8
# pycodestyle                        2.5.0
# pycosat                            0.6.3
# pycparser                          2.20
# pycrypto                           2.6.1
# pycurl                             7.43.0.5
# pydocstyle                         4.0.1
# PyDrive                            1.3.1
# pyflakes                           2.1.1
# Pygments                           2.6.1
# pyjpmesh                           1.1.0
# pylint                             2.4.4
# PyMeeus                            0.3.7
# PyNaCl                             1.3.0
# pyodbc                             4.0.0-unsupported
# pyOpenSSL                          19.1.0
# pyparsing                          2.4.6
# pyproj                             1.9.6
# pyreadline                         2.1
# pyrsistent                         0.16.0
# pyshp                              2.1.0
# PySocks                            1.7.1
# pystan                             2.19.1.1
# pytest                             5.4.1
# pytest-arraydiff                   0.3
# pytest-astropy                     0.8.0
# pytest-astropy-header              0.1.2
# pytest-doctestplus                 0.5.0
# pytest-openfiles                   0.4.0
# pytest-remotedata                  0.3.2
# python-dateutil                    2.8.1
# python-jsonrpc-server              0.3.4
# python-language-server             0.31.9
# pytz                               2019.3
# PyWavelets                         1.1.1
# pywin32                            227
# pywin32-ctypes                     0.2.0
# pywinpty                           0.5.7
# PyYAML                             5.3.1
# pyzmq                              18.1.1
# QDarkStyle                         2.8
# QtAwesome                          0.7.0
# qtconsole                          4.7.2
# QtPy                               1.9.0
# ratelim                            0.1.6
# requests                           2.23.0
# requests-oauthlib                  1.3.0
# rope                               0.16.0
# rsa                                4.0
# Rtree                              0.9.3
# ruamel-yaml                        0.15.87
# scikit-image                       0.16.2
# scikit-learn                       0.23.2
# scipy                              1.4.1
# seaborn                            0.10.0
# selenium                           3.141.0
# Send2Trash                         1.5.0
# setuptools                         46.4.0
# setuptools-git                     1.2
# Shapely                            1.7.0
# simplegeneric                      0.8.1
# singledispatch                     3.4.0.3
# six                                1.14.0
# snowballstemmer                    2.0.0
# sortedcollections                  1.1.2
# sortedcontainers                   2.1.0
# soupsieve                          2.0
# soynlp                             0.0.493
# Sphinx                             2.4.4
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             1.0.3
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.4
# sphinxcontrib-websupport           1.2.1
# spyder                             4.1.2
# spyder-kernels                     1.9.0
# SQLAlchemy                         1.3.15
# statsmodels                        0.11.0
# sympy                              1.5.1
# tables                             3.6.1
# tblib                              1.6.0
# tensorboard                        2.1.1
# tensorflow                         2.1.0
# tensorflow-estimator               2.1.0
# termcolor                          1.1.0
# terminado                          0.8.3
# testpath                           0.4.4
# threadpoolctl                      2.1.0
# toolz                              0.10.0
# torch                              1.7.1
# torchaudio                         0.7.2
# torchvision                        0.8.2
# tornado                            6.0.4
# tqdm                               4.44.1
# traitlets                          4.3.3
# tweepy                             3.10.0
# typing-extensions                  3.7.4.1
# ujson                              1.35
# unicodecsv                         0.14.1
# uritemplate                        3.0.1
# urllib3                            1.25.8
# watchdog                           0.10.2
# wcwidth                            0.1.9
# webdriver-manager                  3.4.2
# webencodings                       0.5.1
# Werkzeug                           1.0.0
# wheel                              0.34.2
# widgetsnbextension                 3.5.1
# win-inet-pton                      1.1.0
# win-unicode-console                0.5
# wincertstore                       0.2
# wordcloud                          1.8.1
# wrapt                              1.12.1
# xgboost                            1.0.2
# xlrd                               1.2.0
# XlsxWriter                         1.2.8
# xlwings                            0.18.0
# xlwt                               1.3.0
# xmltodict                          0.12.0
# yapf                               0.28.0
# zict                               2.0.0
# zipp                               2.2.0

# %% [markdown]
# ## 개발 환경(OS) 및 라이브러리 버전
# - 운영체제(os) Windows10
# - pandas                             0.23.4
# - matplotlib                         3.1.3
# - numpy                              1.18.1

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.impute import KNNImputer
import numpy as np

# %%
df_cus = pd.read_csv("/data/cus_info.csv")

# %%
df_cus.head()
# Out:
#                                               act_id  sex_dit_cd  \
# 0  64aae8dd71e5c0761000db9f9a6779e504e7a4aa9dc097...           1
# 1  5f7c3a8f37d9c268d06130ff0be5d32a1b9ef68c13049f...           1
# 2  1119c23c3a504ca7b75060277410c0f6fb9018ec7638c2...           2
# 3  6d497facfa1ea5901b827335553331f8555fec02a8184f...           2
# 4  b727c78d2cfc246c97b677f29a034399a0c7e7873fff44...           1
#
#    cus_age_stn_cd  ivs_icn_cd  cus_aet_stn_cd  mrz_pdt_tp_sgm_cd  lsg_sgm_cd  \
# 0               4          99               1                  2           3
# 1               6           4               4                  2           5
# 2               7           4               3                  2           5
# 3               6           4               4                  8           5
# 4               5           2               2                  2           5
#
#    tco_cus_grd_cd  tot_ivs_te_sgm_cd  mrz_btp_dit_cd
# 0               3                  6              16
# 1               2                  6               1
# 2               5                  6               9
# 3               3                  6              16
# 4               5                  5              16

# %%
df_cus = df_cus.rename({'act_id':'계좌ID', 'sex_dit_cd':'성별', 'cus_age_stn_cd':'연령대',
               'ivs_icn_cd' : '투자성향', 'cus_aet_stn_cd': '자산구간', 
               'mrz_pdt_tp_sgm_cd': '주거래상품군','lsg_sgm_cd':'lifestage',
               'tco_cus_grd_cd':'서비스등급','tot_ivs_te_sgm_cd': '총투자기간',
              'mrz_btp_dit_cd': '주거래업종구분'}, axis = 1)

# %%
df_cus.head()
# Out:
#                                                 계좌ID  성별  연령대  투자성향  자산구간  \
# 0  64aae8dd71e5c0761000db9f9a6779e504e7a4aa9dc097...   1    4    99     1
# 1  5f7c3a8f37d9c268d06130ff0be5d32a1b9ef68c13049f...   1    6     4     4
# 2  1119c23c3a504ca7b75060277410c0f6fb9018ec7638c2...   2    7     4     3
# 3  6d497facfa1ea5901b827335553331f8555fec02a8184f...   2    6     4     4
# 4  b727c78d2cfc246c97b677f29a034399a0c7e7873fff44...   1    5     2     2
#
#    주거래상품군  lifestage  서비스등급  총투자기간  주거래업종구분
# 0       2          3      3      6       16
# 1       2          5      2      6        1
# 2       2          5      5      6        9
# 3       8          5      3      6       16
# 4       2          5      5      5       16

# %% [markdown]
# ### 고객 데이터 결측값

# %%
df_cus['투자성향'].unique()
# Out:
# array([99,  4,  2,  3,  5,  1,  9,  0], dtype=int64)

# %%
print('투자성향 결측치 : ', end= '')
print(len(df_cus[df_cus['투자성향'] == 99]) / len(df_cus)*100)
print('서비스등급 결측치 : ', end= '')
print(len(df_cus[df_cus['서비스등급'] == 99]) / len(df_cus)*100)
# Out:
# 투자성향 결측치 : 36.870000000000005
# 서비스등급 결측치 : 0.37

# %%
len(df_cus[df_cus['투자성향'] == 99].index)
# Out:
# 3687

# %%
len(df_cus[df_cus['서비스등급'] == 99].index)
# Out:
# 37

# %%
len(df_cus)
# Out:
# 10000

# %% [markdown]
# ### 주식 종복에 대한 코드 정보 결측값
# - 시가총액 규모유형
# - 시장구분

# %%
df_iem = pd.read_csv("/data/iem_info.csv")

# %%
df_iem = df_iem.rename({'iem_cd': '종목코드', 'iem_krl_nm': '종목한글명','btp_cfc_cd' : '종목업종',
              'mkt_pr_tal_scl_tp_cd': '시가총액규모유형','stk_dit_cd':'시장구분'}, axis=1)

# %%
df_iem.head(3)
# Out:
#       종목코드   종목한글명  종목업종  시가총액규모유형  시장구분
# 0  A000020    동화약품     8         2    99
# 1  A000080   하이트진로    14         2     1
# 2  A000180  성창기업지주     5         3    99

# %%
df_iem.shape
# Out:
# (3079, 5)

# %%
print('시가총액규모유형 : ', end = '')
print(len(df_iem[df_iem['시가총액규모유형'] == 99])/len(df_iem)*100, end = '')
print('%')
print('시장구분 : ', end = '')
print(len(df_iem[df_iem['시장구분'] == 99])/len(df_iem)*100, end = '')
print('%')
# Out:
# 시가총액규모유형 : 25.62520298798311%
# 시장구분 : 88.60019486846379%

# %% [markdown]
# ### 종합
# - 투자성향 : 대체
# - 서비스등급 : 결측치 처리 안함
# - 시가총액규모유형 : 대체
# - 시장구분 : drop

# %%
print('투자성향 결측치 : ' + str(len(df_cus[df_cus['투자성향'] == 99]) / len(df_cus)*100) + '%')
print('서비스등급 결측치 : ' + str(len(df_cus[df_cus['서비스등급'] == 99]) / len(df_cus)*100) + '%')
# Out:
# 투자성향 결측치 : 36.870000000000005%
# 서비스등급 결측치 : 0.37%

# %%
print('시가총액규모유형 : ' + str(len(df_iem[df_iem['시가총액규모유형'] == 99])/len(df_iem)*100)+ '%')
print('시장구분 : ' + str(len(df_iem[df_iem['시장구분'] == 99])/len(df_iem)*100)+ '%')
# Out:
# 시가총액규모유형 : 25.62520298798311%
# 시장구분 : 88.60019486846379%

# %% [markdown]
# ### 결측값 처리
# - 행을 지우는 건 지양 : 계좌id가 없어질 수 있음
# - 시가총액규모유형 : 유가증권시장의 경우 6월부터 8월 마지막 영업일까지 하루평균 시가총액 순서로 1~100위는 대형주, 101~300위는 중형주, 그 외는 소형주로 분류. 코스닥시장은 중형주 기준이 101~400위. / 유가증권시장(코스피), 코스닥
# - 코스피에서 시가총액 순위를 기준으로 만든 대형주, 중형주, 소형주 지수가 있음, 대형주 시가총액 1~100위, 시가총액 101 ~ 300위, 시가총액 301 ~

# %%
# 시장구분 열 drop 
df_iem = df_iem.drop('시장구분', axis = 1)

# %%
# 투자성향 분포 확인 
df_cus['투자성향'].value_counts()
# Out:
# 99    3687
# 4     1858
# 3     1669
# 2     1467
# 5      935
# 1      210
# 0      171
# 9        3
# Name: 투자성향, dtype: int64

# %% [markdown]
# #### 시가총액규모유형 전처리 방법
# - 행을 지우는 건 지양 : 주식중목코드가 없어질 수 있음
# - KODEX|TIGER|KINDEX|KTOP|KBSTAR|ARIRANG|HANARO|KOSEF 은 파생상품 혹은 펀드이므로, 새로운 라벨 "4" 추가.
# - ~우 인 데이터도 있음.. 05. 우량주 추가
# - 01: 대형주, 02: 중형주, 03: 소형주, 04: 파생상품, 05. 우량주, 99: 기타

# %%
# 시가총액규모유형 분포 확인 
df_iem['시가총액규모유형'].value_counts()
# Out:
# 3     1577
# 99     789
# 2      512
# 1      201
# Name: 시가총액규모유형, dtype: int64

# %%
df_iem_null = df_iem[df_iem['시가총액규모유형'] == 99]

# %%
df_iem_null.to_csv("시가총액규모유형_결측치.csv", index = False)

# %%
 # https://zephyrus1111.tistory.com/46
df_iem.query('종목한글명.str.contains("KODEX|TIGER|KINDEX|KTOP|KBSTAR|ARIRANG|HANARO|KOSEF")', engine='python')['시가총액규모유형'].replace(99,4, inplace = True)

# %%
 # https://zephyrus1111.tistory.com/46
index_04 = df_iem.query('종목한글명.str.contains("KODEX|TIGER|KINDEX|KTOP|KBSTAR|ARIRANG|HANARO|KOSEF")', engine='python')['시가총액규모유형'].index

# %%
# 04 파생상품 추가 
for i in index_04: 
    df_iem.iloc[i, -1] = 4
    #print(df_iem.iloc[i, -1])

# %%
df_iem['시가총액규모유형'].value_counts()
# Out:
# 3     1577
# 2      512
# 4      395
# 99     394
# 1      201
# Name: 시가총액규모유형, dtype: int64

# %%
index_05 = []
for i in range(len(df_iem)):
    if df_iem.loc[i, '종목한글명'].endswith('우'):
        index_05.append(i)

# %%
for i in index_05:
    df_iem.iloc[i, -1] = 5
    #print(df_iem.loc[i, '종목한글명'])

# %%
df_iem['시가총액규모유형'].value_counts()
# Out:
# 3     1577
# 2      511
# 4      395
# 99     275
# 1      200
# 5      121
# Name: 시가총액규모유형, dtype: int64

# %%
df_iem.to_csv("iem_info_missingvalue_out.csv", index = False)

# %%
df_iem.shape
# Out:
# (3079, 4)

# %%
df_iem[df_iem['시가총액규모유형'] == 4]
# Out:
#          종목코드                     종목한글명  종목업종  시가총액규모유형
# 384   A091160                 KODEX 반도체    14         4
# 385   A091180                 KODEX 자동차    14         4
# 405   A099140             KODEX China H    14         4
# 410   A101280          KODEX 일본TOPIX100    14         4
# 421   A104520                 KOSEF 블루칩    14         4
# 441   A117700                  KODEX 건설    14         4
# 445   A122630                KODEX 레버리지    14         4
# 450   A123310                 TIGER 인버스    14         4
# 464   A131890           KINDEX 삼성그룹동일가중    14         4
# 465   A133690            TIGER 미국나스닥100    14         4
# 473   A139220              TIGER 200 건설    14         4
# 474   A139250           TIGER 200 에너지화학    14         4
# 475   A139270              TIGER 200 금융    14         4
# 476   A139280                TIGER 경기방어    14         4
# 481   A140710                  KODEX 운송    14         4
# 486   A143850       TIGER 미국S&P500선물(H)    14         4
# 493   A152100               ARIRANG 200    14         4
# 494   A152280              KOSEF 200 선물    14         4
# 500   A157500                  TIGER 증권    14         4
# 505   A168300                KTOP 코스피50    14         4
# 507   A169950            KODEX 중국본토 A50    14         4
# 512   A174360      KBSTAR 중국본토대형주CSI100    14         4
# 531   A195930       TIGER 유로스탁스50(합성 H)    14         4
# 532   A196030     KINDEX 일본TOPIX레버리지(H)    14         4
# 535   A200030        KODEX 미국S&P산업재(합성)    14         4
# 536   A200050          KODEX 독일MSCI(합성)    14         4
# 546   A211560                TIGER 배당성장    14         4
# 548   A213630  ARIRANG 미국다우존스고배당주(합성 H)    14         4
# 562   A219480       KODEX 미국S&P500선물(H)    14         4
# 567   A222180       ARIRANG 스마트베타 Value    14         4
# ...       ...                       ...   ...       ...
# 3009  A322150            KINDEX 스마트하이베타    14         4
# 3012  A325020                KODEX 배당가치    14         4
# 3014  A326230             KBSTAR 내수주플러스    14         4
# 3015  A329200           TIGER 부동산인프라고배당    14         4
# 3016  A329650             KODEX TRF3070    14         4
# 3017  A332610         ARIRANG 미국단기우량회사채    14         4
# 3022  A333960         ARIRANG KS모멘텀가중TR    14         4
# 3023  A334690           KBSTAR 팔라듐선물(H)    14         4
# 3024  A334700        KBSTAR 팔라듐선물인버스(H)    14         4
# 3027  A337140              KODEX 코스피대형주    14         4
# 3032  A341850       TIGER KIS부동산인프라채권TR    14         4
# 3041  A352560         KODEX 다우존스미국리츠(H)    14         4
# 3049  A364960       TIGER KRX BBIG K-뉴딜    14         4
# 3050  A364970          TIGER KRX바이오K-뉴딜    14         4
# 3055  A367740             HANARO Fn5G산업    14         4
# 3056  A367770           KBSTAR Fn수소경제테마    14         4
# 3057  A368190      HANARO Fn K-뉴딜디지털플러스    14         4
# 3058  A368200      KBSTAR Fn K-뉴딜디지털플러스    14         4
# 3060  A371150            KBSTAR 차이나항셍테크    14         4
# 3063  A373490          KODEX K-이노베이션액티브    14         4
# 3065  A376250          ARIRANG 탄소효율그린뉴딜    14         4
# 3066  A376410            TIGER 탄소효율그린뉴딜    14         4
# 3067  A377990            TIGER Fn신재생에너지    14         4
# 3068  A379790         KBSTAR 유로스탁스50(H)    14         4
# 3070  A380340            KINDEX Fn5G플러스    14         4
# 3072  A381560           HANARO Fn전기&수소차    14         4
# 3075  A385520            KODEX K-미래차액티브    14         4
# 3076  A388280            KBSTAR Fn컨택트대표    14         4
# 3077  A388420         KBSTAR 비메모리반도체액티브    14         4
# 3078  A394350     KOSEF 릭소글로벌퓨처모빌리티MSCI    14         4
#
# [395 rows x 4 columns]

# %%
df_iem[df_iem['시가총액규모유형'] == 5]
# Out:
#          종목코드      종목한글명  종목업종  시가총액규모유형
# 4     A000325     노루홀딩스우     2         5
# 17    A001465       BYC우    14         5
# 19    A001525        동양우    11         5
# 42    A003075    코오롱글로벌우     1         5
# 46    A003535    한화투자증권우     2         5
# 57    A004255       NPC우    12         5
# 58    A004365        세방우     6         5
# 63    A004545     깨끗한나라우    10         5
# 70    A004985      성신양회우    11         5
# 73    A005257   녹십자홀딩스2우     5         5
# 74    A005305      롯데칠성우    14         5
# 116   A008775      호텔신라우     7         5
# 121   A009155      삼성전기우     9         5
# 136   A011155    CJ씨푸드1우    14         5
# 156   A014915      성문전자우     9         5
# 163   A016385    KG동부제철우    11         5
# 175   A019175      신풍제약우     8         5
# 206   A032685      소프트센우     7         5
# 426   A108675    LX하우시스우    12         5
# 489   A145995       삼양사우    14         5
# 672   A29923L  세븐브로이양평2우    14         5
# 675   A30018L     팝스라인2우    14         5
# 691   A31134K   테디아일랜드1우    14         5
# 714   A32316K       테바1우    14         5
# 730   A34385K  금축인터내셔널1우    14         5
# 740   A35320K     대덕전자1우     9         5
# 761   A38380K    LX홀딩스1우    14         5
# 766   A000105      유한양행우     8         5
# 768   A000145  하이트진로홀딩스우     2         5
# 777   A000545      흥국화재우     2         5
# ...       ...        ...   ...       ...
# 2317  A000215        DL우     1         5
# 2318  A000225     유유제약1우     8         5
# 2326  A000725      현대건설우     1         5
# 2339  A001725      신영증권우     2         5
# 2340  A001795      대한제당우    14         5
# 2356  A002995      금호건설우     1         5
# 2365  A003415      쌍용양회우    14         5
# 2367  A003465      유화증권우     2         5
# 2370  A003555        LG우     2         5
# 2378  A004135     대덕GDS우    14         5
# 2391  A00499K      롯데지주우     2         5
# 2398  A005745  크라운해태홀딩스우     2         5
# 2399  A005935      삼성전자우     9         5
# 2402  A006125   SK디스커버리우     2         5
# 2408  A006805    미래에셋증권우     2         5
# 2416  A007575      일양약품우     8         5
# 2420  A00806K       대덕1우     2         5
# 2427  A009275        신원우    14         5
# 2461  A014285      금강공업우    11         5
# 2534  A03473K        SK우     2         5
# 2666  A071055    한국금융지주우     2         5
# 2692  A084695     대상홀딩스우     2         5
# 2699  A090435    아모레퍼시픽우    12         5
# 2719  A096775   SK이노베이션우    12         5
# 2722  A097955   CJ제일제당 우    14         5
# 2949  A27863K   스터디플래닛1우    14         5
# 2972  A294090      이오플로우    10         5
# 3026  A33637K  솔루스첨단소재1우     9         5
# 3048  A36328K    티와이홀딩스우     2         5
# 3064  A37550K     DL이앤씨우    14         5
#
# [121 rows x 4 columns]

# %% [markdown]
# #### 투자성향 전처리 방법
# - knn 으로 99에 해당하는 값 3687개 중에서 1000개만 99로 남김 (99에 대한 학습도 필요하니깐)
# - 나머지 값은 null값으로 만듬
# - knn 으로 n=3일때의 예측값 대치
# - 35, 36 등과 같이 범주형 변수가 아닌 경우, 99로 바꿈

# %%
df_cus = pd.read_csv("/data/cus_info.csv")

# %%
df_cus.head()
# Out:
#                                                 계좌ID  성별  연령대 투자성향  자산구간  \
# 0  64aae8dd71e5c0761000db9f9a6779e504e7a4aa9dc097...   1    4   99     1
# 1  5f7c3a8f37d9c268d06130ff0be5d32a1b9ef68c13049f...   1    6    4     4
# 2  1119c23c3a504ca7b75060277410c0f6fb9018ec7638c2...   2    7    4     3
# 3  6d497facfa1ea5901b827335553331f8555fec02a8184f...   2    6    4     4
# 4  b727c78d2cfc246c97b677f29a034399a0c7e7873fff44...   1    5    2     2
#
#    주거래상품군  lifestage  서비스등급  총투자기간  주거래업종구분
# 0       2          3      3      6       16
# 1       2          5      2      6        1
# 2       2          5      5      6        9
# 3       8          5      3      6       16
# 4       2          5      5      5       16

# %%
df_cus = df_cus.rename({'act_id':'계좌ID', 'sex_dit_cd':'성별', 'cus_age_stn_cd':'연령대',
               'ivs_icn_cd' : '투자성향', 'cus_aet_stn_cd': '자산구간', 
               'mrz_pdt_tp_sgm_cd': '주거래상품군','lsg_sgm_cd':'lifestage',
               'tco_cus_grd_cd':'서비스등급','tot_ivs_te_sgm_cd': '총투자기간',
              'mrz_btp_dit_cd': '주거래업종구분'}, axis = 1)

# %%
df_cus['투자성향'].replace({99, '99'}, inplace = True)

# %%
df_cus['투자성향'] = df_cus['투자성향'].astype('str')

# %%
type(df_cus['투자성향'][3])
# Out:
# str

# %%
df_cus_null = df_cus.copy()

# %%
type(df_cus_null['투자성향'][3])
# Out:
# str

# %%
index_null = df_cus_null[df_cus_null['투자성향'] == '99'][:-1000].index

# %%
len(index_null)
# Out:
# 2687

# %%
for i in index_null:
    df_cus_null.iloc[i, 3] = np.nan

# %%
df_cus_null.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
# 계좌ID         10000 non-null object
# 성별           10000 non-null int64
# 연령대          10000 non-null int64
# 투자성향         7313 non-null object
# 자산구간         10000 non-null int64
# 주거래상품군       10000 non-null int64
# lifestage    10000 non-null int64
# 서비스등급        10000 non-null int64
# 총투자기간        10000 non-null int64
# 주거래업종구분      10000 non-null int64
# dtypes: int64(8), object(2)
# memory usage: 781.3+ KB

# %%
# https://www.analyticsvidhya.com/blog/2020/07/knnimputer-a-robust-way-to-impute-missing-values-using-scikit-learn/
imputer = KNNImputer(n_neighbors = 3)

# %%
imputed = imputer.fit_transform(df_cus_null.iloc[:, 1:])

# %%
df_imputer = pd.DataFrame(imputed, columns = df_cus_null.columns[1:])

# %%
df_imputer['투자성향'].value_counts()
# Out:
# 4.000000     2104
# 3.000000     2018
# 2.000000     1586
# 99.000000    1021
# 5.000000      950
# 3.333333      347
# 3.666667      296
# 2.666667      240
# 1.000000      219
# 2.333333      205
# 0.000000      178
# 4.333333      104
# 35.000000     101
# 35.333333      96
# 34.666667      74
# 34.333333      64
# 1.666667       61
# 35.666667      59
# 4.666667       46
# 1.333333       42
# 66.666667      33
# 67.000000      30
# 67.333333      29
# 34.000000      24
# 36.000000      23
# 0.666667       12
# 33.666667      10
# 67.666667       9
# 36.333333       7
# 66.333333       5
# 66.000000       3
# 9.000000        3
# 5.333333        1
# Name: 투자성향, dtype: int64

# %%
df_imputer['투자성향'] = df_imputer['투자성향'].astype('int')
df_imputer['성별'] = df_imputer['성별'].astype('int')
df_imputer['연령대'] = df_imputer['연령대'].astype('int')
df_imputer['자산구간'] = df_imputer['자산구간'].astype('int')
df_imputer['주거래상품군'] = df_imputer['주거래상품군'].astype('int')
df_imputer['lifestage'] = df_imputer['lifestage'].astype('int')
df_imputer['서비스등급'] = df_imputer['서비스등급'].astype('int')
df_imputer['총투자기간'] = df_imputer['총투자기간'].astype('int')
df_imputer['주거래업종구분'] = df_imputer['주거래업종구분'].astype('int')

# %%
df_imputer['투자성향'].value_counts()
# Out:
# 3     2661
# 4     2254
# 2     2031
# 99    1021
# 5      951
# 1      322
# 35     256
# 0      190
# 34     162
# 67      68
# 66      41
# 36      30
# 33      10
# 9        3
# Name: 투자성향, dtype: int64

# %%
df_imputer['투자성향'].replace(35, 99, inplace=True)
df_imputer['투자성향'].replace(34, 99, inplace=True)
df_imputer['투자성향'].replace(67, 99, inplace=True)
df_imputer['투자성향'].replace(36, 99, inplace=True)
df_imputer['투자성향'].replace(33, 99, inplace=True)
df_imputer['투자성향'].replace(66, 99, inplace=True)

# %%
df_imputer['투자성향'].value_counts()
# Out:
# 3     2661
# 4     2254
# 2     2031
# 99    1588
# 5      951
# 1      322
# 0      190
# 9        3
# Name: 투자성향, dtype: int64

# %%
df_imputer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
# 성별           10000 non-null int32
# 연령대          10000 non-null int32
# 투자성향         10000 non-null int32
# 자산구간         10000 non-null int32
# 주거래상품군       10000 non-null int32
# lifestage    10000 non-null int32
# 서비스등급        10000 non-null int32
# 총투자기간        10000 non-null int32
# 주거래업종구분      10000 non-null int32
# dtypes: int32(9)
# memory usage: 351.6 KB

# %%
df_imputer_ver2 = pd.concat([df_cus_null['계좌ID'], df_imputer], axis = 1)

# %%
df_imputer_ver2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
# 계좌ID         10000 non-null object
# 성별           10000 non-null int32
# 연령대          10000 non-null int32
# 투자성향         10000 non-null int32
# 자산구간         10000 non-null int32
# 주거래상품군       10000 non-null int32
# lifestage    10000 non-null int32
# 서비스등급        10000 non-null int32
# 총투자기간        10000 non-null int32
# 주거래업종구분      10000 non-null int32
# dtypes: int32(9), object(1)
# memory usage: 429.8+ KB

# %%
df_imputer_ver2
# Out:
#                                                    계좌ID  성별  연령대  투자성향  자산구간  \
# 0     64aae8dd71e5c0761000db9f9a6779e504e7a4aa9dc097...   1    4     4     1
# 1     5f7c3a8f37d9c268d06130ff0be5d32a1b9ef68c13049f...   1    6     4     4
# 2     1119c23c3a504ca7b75060277410c0f6fb9018ec7638c2...   2    7     4     3
# 3     6d497facfa1ea5901b827335553331f8555fec02a8184f...   2    6     4     4
# 4     b727c78d2cfc246c97b677f29a034399a0c7e7873fff44...   1    5     2     2
# 5     4f330270cd37d758fbe9dfe45e0c40ed4579ab6b87a648...   1    5     3     4
# 6     407a1110ee9394a0d7778e13de9327117182a68e545372...   1    8    99     2
# 7     2c17850345fbac9b3f004773972fd72a716228b3896e6f...   2    4     3     4
# 8     812f478747ca7497e60a6643ca82a6d5c7323980291a42...   1    4     3     4
# 9     51c0d868a0d91c15a5eefdd68fbca1d1c5e3215fcebb33...   1    5     5     3
# 10    127188207e133cd6361a6966376eea6183b31077a82bd3...   1    4     3     3
# 11    f6bfe08cc25c9583f61e0cb573a6f7a2593e8314732cb9...   1    8     4     6
# 12    634c1db2c131ef2f3a404fb533fcda64fa517b0fbe9316...   1    7     3     2
# 13    249201e1820bafc4e0b1eaa4d255588c7c109ba390611c...   1    5     4     1
# 9988  b2df4d87d04c0685e6301bd4b202533d8b76669401f1d8...   1    2    99     1
# 9989  8289fcfdfd0a34b063ea3a5778cdbe90186211213ab49f...   2    7    99     2
# 9990  3e51702eea7420c4c0c68831b42bc7dea1b79064df6692...   2    6    99     2
# 9991  d985575fa13aeb48146e5e7e72347500cdaf9d5be96794...   1    5     5     2
# 9992  6cfd54d944e2aa4f8bb1f1843685b39039c4dd02ad6535...   2    3     3     1
# 9993  6d1dde7a559a771e6f88990cd697564226fa89ecffa728...   1    6     1     1
# 9994  d00e9e5bbb618c1f37df1c6ecf6490ee4bd9357b76be53...   1    5     3     1
# 9995  2fdd734bf8fc04c0d484ddc1d021622a1cdc802705702e...   1    9     4     2
# 9996  720aa28d24bfa8fbeddf4fe625cb53af0a6f7ff2d526de...   2    2     3     1
# 9997  7702030b3b0760e6b37c8a3e8ed58611b1b85913526ad1...   2    7     4     2
# 9998  4006ddaa5673365096b9dd5965e20db866f6523c162f79...   1    5    99     5
# 9999  564af3cf975ed4fa05148ada689d5002e9c2d43dee9481...   1    6     0     5
#
#       주거래상품군  lifestage  서비스등급  총투자기간  주거래업종구분
# 0          2          3      3      6       16
# 1          2          5      2      6        1
# 2          2          5      5      6        9
# 3          8          5      3      6       16
# 4          2          5      5      5       16
# 5          2          5      4      6       10
# 6          2          5      5      6       16
# 7          2          4      3      5       10
# 8          2          3      3      6       10
# 9          2          7      3      6        5
# 10         2          3      5      5       16
# 11         2          7      2      5        5
# 12         2          5      3      6       14
# 13         2          5      9      5       16
# 14         2          5      3      5        2
# 15         2          5      3      6       13
# 16         2          5      5      5       15
# 17         2          6      9      5        2
# 18         2          9      4      6        8
# 19         2          4      5      5       16
# 20         2          9      4      5        7
# 21         2          5      1      6       10
# 22         2          7      4      5       10
# 23         2          9      3      6       10
# 24         2          5      5      5       16
# 25         2          6      3      5        5
# 26         2          5      4      6        6
# 27         2          7      4      5       13
# 28         2          9      2      6        4
# 29         2          5      2      5       13
# ...      ...        ...    ...    ...      ...
# 9970       2          2      5      2        2
# 9971       2          2      9      2       16
# 9972       2          9      4      2       15
# 9973       2          4      9      1       16
# 9974       2          5      5      2        9
# 9975       2          2      9      1        6
# 9976       2          7      4      2        4
# 9977       2          4      5      2       10
# 9978       2          5      5      2        9
# 9979       2          3      9      2       14
# 9980       2          3      5      1        5
# 9981       2          5      9      2        9
# 9982       2          2      9      1        6
# 9983       2          8      9      2        9
# 9984       2          6      4      1       16
# 9985       2          7      9      2        3
# 9986       2          3      9      2        2
# 9987       2          6      4      2       10
# 9988       2          2      9      5       13
# 9989       2          6      5      2        2
# 9990       2          6      5      2        8
# 9991       2          5      9      2        9
# 9992       2          4      9      1       14
# 9993       2          7      5      2       10
# 9994       2          7      9      2       16
# 9995       2          9      5      2       16
# 9996       2          2      9      1       16
# 9997       2          5      5      2       16
# 9998       2          5      3      2        5
# 9999       2          5      3      5        2
#
# [10000 rows x 10 columns]

# %%
df_imputer_ver2.to_csv("cus_info_missingvalue_out.csv", index= False)

# %% [markdown]
# ### Baseline 모델로 모델 돌리기

# %%
import pandas as pd
pd.set_option("display.max_row", 100)
pd.set_option("display.max_column", 100)
import numpy as np
import os

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error as mse
from sklearn.model_selection import train_test_split, StratifiedKFold, KFold
from lightgbm import LGBMRegressor

# %%
cus = pd.read_csv("/data/cus_info_missingvalue_out.csv")
iem = pd.read_csv("/data/iem_info_missingvalue_out.csv")
hist = pd.read_csv("/data/stk_bnc_hist.csv")
train = pd.read_csv("/data/stk_hld_train.csv")
test = pd.read_csv("/data/stk_hld_test.csv")

submission = pd.read_csv("/data/sample_submission.csv")

# %%
cus = cus.rename({'계좌ID':'act_id','성별':'sex_dit_cd','연령대':'cus_age_stn_cd',
                '투자성향':'ivs_icn_cd', '자산구간':'cus_aet_stn_cd', 
               '주거래상품군':'mrz_pdt_tp_sgm_cd','lifestage':'lsg_sgm_cd',
               '서비스등급':'tco_cus_grd_cd','총투자기간':'tot_ivs_te_sgm_cd',
              '주거래업종구분':'mrz_btp_dit_cd'}, axis = 1)

# %%
iem = iem.rename({'종목코드':'iem_cd','종목한글명':'iem_krl_nm', '종목업종': 'btp_cfc_cd',
              '시가총액규모유형':'mkt_pr_tal_scl_tp_cd','시장구분':'stk_dit_cd'}, axis=1)

# %%
iem.columns
# Out:
# Index(['iem_cd', 'iem_krl_nm', 'btp_cfc_cd', 'mkt_pr_tal_scl_tp_cd'], dtype='object')

# %%
iem
# Out:
#        iem_cd             iem_krl_nm  btp_cfc_cd  mkt_pr_tal_scl_tp_cd
# 0     A000020                   동화약품           8                     2
# 1     A000080                  하이트진로          14                     2
# 2     A000180                 성창기업지주           5                     3
# 3     A000227                유유제약2우B           8                    99
# 4     A000325                 노루홀딩스우           2                     5
# 5     A000440                 중앙에너비스           7                     3
# 6     A000590                  CS홀딩스           2                     3
# 7     A000670                     영풍          11                     2
# 8     A000700                  유수홀딩스           5                     3
# 9     A001000                   신라섬유           7                     3
# 10    A001020                 페이퍼코리아          10                     3
# 11    A001070                   대한방직          14                     3
# 12    A001270                   부국증권           2                     3
# 13    A001290                  상상인증권           2                     3
# 14    A001390                  KG케미칼          12                     3
# 15    A001450                   현대해상           2                     2
# 16    A001460                    BYC          14                     3
# 17    A001465                   BYC우          14                     5
# 18    A001470                   삼부토건           1                     2
# 19    A001525                    동양우          11                     5
# 20    A001780                    알루코          11                     3
# 21    A001790                   대한제당          14                     3
# 22    A001799                대한제당3우B          14                    99
# 23    A001800                 오리온홀딩스           2                     2
# 24    A001810                   무림SP          10                     3
# 25    A002030                    아세아           5                     3
# 26    A002070                    비비안          14                     3
# 27    A002170                   삼양통상          14                     3
# 28    A002230                   피에스텍          10                     3
# 29    A002290                 삼일기업공사           1                     3
# 30    A002300                   한국제지          14                     3
# 31    A002310                  아세아제지          10                     3
# 32    A002360                SH에너지화학          12                     3
# 33    A002420                   세기상사           5                     3
# 34    A002460                   화성산업           1                     3
# 35    A002550                 KB손해보험          14                     2
# 36    A002710                  TCC스틸          11                     3
# 37    A002790                   아모레G          12                     1
# 38    A002840                   미원상사          12                     2
# 39    A002900                    TYM           3                     3
# 70578     109  IDX70579       0
# 70579     195  IDX70580       0
# 70580    1227  IDX70581       0
# 70581       4  IDX70582       0
# 70582      71  IDX70583       0
# 70583      25  IDX70584       0
# 70584      49  IDX70585       0
# 70585      70  IDX70586       0
# 70586     110  IDX70587       0
# 70587     287  IDX70588       0
# 70588     357  IDX70589       0
# 70589      16  IDX70590       0
# 70590      62  IDX70591       0
# 70591      23  IDX70592       0
# 70592     103  IDX70593       0
# 70593     858  IDX70594       0
# 70594      11  IDX70595       0
# 70595       4  IDX70596       0
#
# [70596 rows x 6 columns]

# %%
# 앞서 언급한 것처럼 베이스라인에서는 "hist_d" column을 임의로 생성하여 모델을 학습시키도록 하겠습니다.
# 베이스라인에서는 "hold_d"값, 즉 주식 보유기간의 0.6배에 해당하는 기간을 임의로 설정하여 "hist_d"를 생성하였습니다.
# 결국 모델은 "hist_d"만큼 주식을 보유 했을때의 "hold_d"를 예측하게 될 것입니다.

train["hist_d"] = train["hold_d"]*0.6
train.hist_d = np.trunc(train["hist_d"])

# %%
train.head(3)
# Out:
#                                               act_id   iem_cd    byn_dt  \
# 0  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A006360  20180726
# 1  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A005930  20180131
# 2  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A005070  20180517
#
#    hold_d  hist_d
# 0      11     6.0
# 1      80    48.0
# 2       5     3.0

# %%
# train과 test에 고객정보(cus_info)와 주식정보(iem_info)를 추가하겠습니다.

train_data = pd.merge(train, cus, how = "left", on = ["act_id"])
train_data = pd.merge(train_data, iem, how = "left", on = ["iem_cd"])

test_data = pd.merge(test, cus, how = "left", on = ["act_id"])
test_data = pd.merge(test_data, iem, how = "left", on = ["iem_cd"])

# %%
train_data.head(3)
# Out:
#                                               act_id   iem_cd    byn_dt  \
# 0  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A006360  20180726
# 1  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A005930  20180131
# 2  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A005070  20180517
#
#    hold_d  hist_d  sex_dit_cd  cus_age_stn_cd  ivs_icn_cd  cus_aet_stn_cd  \
# 0      11     6.0           1               9           3               2
# 1      80    48.0           1               9           3               2
# 2       5     3.0           1               9           3               2
#
#    mrz_pdt_tp_sgm_cd  lsg_sgm_cd  tco_cus_grd_cd  tot_ivs_te_sgm_cd  \
# 0                  2           9               5                  5
# 1                  2           9               5                  5
# 2                  2           9               5                  5
#
#    mrz_btp_dit_cd iem_krl_nm  btp_cfc_cd  mkt_pr_tal_scl_tp_cd
# 0               8       GS건설           1                     1
# 1               8       삼성전자           9                     1
# 2               8     코스모신소재          12                     2

# %%
# train_data에서 Y값을 추출한 후 hold_d column을 지워주겠습니다.

train_label = train_data["hold_d"]
train_data.drop(["hold_d"], axis = 1, inplace = True)

# %%
# 추가적으로 약간의 전처리를 통해 train data와 test data를 구성하겠습니다.

hist["stk_p"] = hist["tot_aet_amt"] / hist["bnc_qty"]
hist = hist.fillna(0)

train_data = pd.merge(train_data, hist, how = "left", on = ["act_id", "iem_cd"])
train_data = train_data[(train_data["byn_dt"] == train_data["bse_dt"])]
train_data.reset_index(drop = True, inplace = True)

test_data = pd.merge(test_data, hist, how = "left", on = ["act_id", "iem_cd"])
test_data = test_data[(test_data["byn_dt"] == test_data["bse_dt"])]
test_data.reset_index(drop = True, inplace = True)

train_data = train_data.drop(["act_id", "iem_cd", "byn_dt", "bse_dt"], axis = 1)
test_data = test_data.drop(["act_id", "iem_cd", "byn_dt", "submit_id", "hold_d", "bse_dt"], axis = 1)

L_encoder = LabelEncoder()
L_encoder.fit(iem["iem_krl_nm"])
train_data["iem_krl_nm"] = L_encoder.transform(train_data["iem_krl_nm"])
test_data["iem_krl_nm"] = L_encoder.transform(test_data["iem_krl_nm"])

# %%
train_data.head(3)
# Out:
#    hist_d  sex_dit_cd  cus_age_stn_cd  ivs_icn_cd  cus_aet_stn_cd  \
# 0     6.0           1               9           3               2
# 1    48.0           1               9           3               2
# 2     3.0           1               9           3               2
#
#    mrz_pdt_tp_sgm_cd  lsg_sgm_cd  tco_cus_grd_cd  tot_ivs_te_sgm_cd  \
# 0                  2           9               5                  5
# 1                  2           9               5                  5
# 2                  2           9               5                  5
#
#    mrz_btp_dit_cd  iem_krl_nm  btp_cfc_cd  mkt_pr_tal_scl_tp_cd  bnc_qty  \
# 0               8         101           1                     1    274.0
# 1               8        1361           9                     1      2.0
# 2               8        2530          12                     2    786.0
#
#    tot_aet_amt  stk_par_pr      stk_p
# 0   11782000.0      5000.0    43000.0
# 1    4990000.0      5000.0  2495000.0
# 2   14619600.0      1000.0    18600.0

# %%
test_data.head(3)
# Out:
#    hist_d  sex_dit_cd  cus_age_stn_cd  ivs_icn_cd  cus_aet_stn_cd  \
# 0     153           1               9           3               2
# 1     335           1               9           3               2
# 2     139           1               9           3               2
#
#    mrz_pdt_tp_sgm_cd  lsg_sgm_cd  tco_cus_grd_cd  tot_ivs_te_sgm_cd  \
# 0                  2           9               5                  5
# 1                  2           9               5                  5
# 2                  2           9               5                  5
#
#    mrz_btp_dit_cd  iem_krl_nm  btp_cfc_cd  mkt_pr_tal_scl_tp_cd  bnc_qty  \
# 0               8         418           4                     1    300.0
# 1               8        2230          10                     3    198.0
# 2               8        1515          13                     2    138.0
#
#    tot_aet_amt  stk_par_pr    stk_p
# 0    3945000.0      5000.0  13150.0
# 1    2524500.0       500.0  12750.0
# 2    4291800.0       500.0  31100.0

# %%
train_data.reset_index(drop = True, inplace=True)
train_label.reset_index(drop = True, inplace=True)

# %%
models = []

folds = KFold(n_splits=10)
for train_idx, val_idx in folds.split(train_data):
    
    train_x = train_data.iloc[train_idx, :]
    train_y = train_label[train_idx]
    val_x = train_data.iloc[val_idx, :]
    val_y = train_label[val_idx]
    
    model = LGBMRegressor(objective= "regression",
                          max_depth= 8,
                          n_estimators= 2000,
                          learning_rate= 0.01,
                          num_leaves = 31)
    
    model.fit(train_x, train_y,
              eval_set=[(val_x, val_y)],
              eval_metric=["rmse"],
              early_stopping_rounds=300,
              verbose=500)
    
    models.append(model)
# Out:
# Training until validation scores don't improve for 300 rounds
# [500]	valid_0's rmse: 4.21693	valid_0's l2: 17.7825
# [1000]	valid_0's rmse: 4.08441	valid_0's l2: 16.6824
# [1500]	valid_0's rmse: 4.04913	valid_0's l2: 16.3955
# [2000]	valid_0's rmse: 4.03698	valid_0's l2: 16.2972
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's rmse: 4.03698	valid_0's l2: 16.2972
# Training until validation scores don't improve for 300 rounds
# [500]	valid_0's rmse: 1.2419	valid_0's l2: 1.54233
# Early stopping, best iteration is:
# [698]	valid_0's rmse: 1.17745	valid_0's l2: 1.38638
# Training until validation scores don't improve for 300 rounds
# [500]	valid_0's rmse: 0.685671	valid_0's l2: 0.470145
# [1000]	valid_0's rmse: 0.477619	valid_0's l2: 0.22812
# Early stopping, best iteration is:
# [794]	valid_0's rmse: 0.47717	valid_0's l2: 0.227692
# Training until validation scores don't improve for 300 rounds
# [500]	valid_0's rmse: 0.574361	valid_0's l2: 0.32989
# [1000]	valid_0's rmse: 0.413046	valid_0's l2: 0.170607
# Early stopping, best iteration is:
# [1040]	valid_0's rmse: 0.412917	valid_0's l2: 0.170501
# Training until validation scores don't improve for 300 rounds
# [500]	valid_0's rmse: 0.545353	valid_0's l2: 0.29741
# [1000]	valid_0's rmse: 0.401781	valid_0's l2: 0.161428
# [1500]	valid_0's rmse: 0.401586	valid_0's l2: 0.161271
# [2000]	valid_0's rmse: 0.401618	valid_0's l2: 0.161297
# Did not meet early stopping. Best iteration is:
# [1822]	valid_0's rmse: 0.401469	valid_0's l2: 0.161178
# Training until validation scores don't improve for 300 rounds
# [500]	valid_0's rmse: 0.51201	valid_0's l2: 0.262154
# [1000]	valid_0's rmse: 0.39824	valid_0's l2: 0.158595
# Early stopping, best iteration is:
# [1047]	valid_0's rmse: 0.398161	valid_0's l2: 0.158532
# Training until validation scores don't improve for 300 rounds
# [500]	valid_0's rmse: 0.449645	valid_0's l2: 0.202181
# [1000]	valid_0's rmse: 0.380128	valid_0's l2: 0.144497
# Early stopping, best iteration is:
# [914]	valid_0's rmse: 0.380094	valid_0's l2: 0.144472
# Training until validation scores don't improve for 300 rounds
# [500]	valid_0's rmse: 0.427147	valid_0's l2: 0.182454
# [1000]	valid_0's rmse: 0.379859	valid_0's l2: 0.144293
# [1500]	valid_0's rmse: 0.379833	valid_0's l2: 0.144273
# Early stopping, best iteration is:
# [1284]	valid_0's rmse: 0.379829	valid_0's l2: 0.14427
# Training until validation scores don't improve for 300 rounds
# [500]	valid_0's rmse: 0.410704	valid_0's l2: 0.168678
# [1000]	valid_0's rmse: 0.382078	valid_0's l2: 0.145984
# Early stopping, best iteration is:
# [906]	valid_0's rmse: 0.382069	valid_0's l2: 0.145977
# Training until validation scores don't improve for 300 rounds
# [500]	valid_0's rmse: 0.573733	valid_0's l2: 0.32917
# Early stopping, best iteration is:
# [491]	valid_0's rmse: 0.573047	valid_0's l2: 0.328383

# %%
result = []
for i in models:
    result.append(i.predict(test_data))
predict = np.mean(result, axis = 0)

# %%
predict[:20]
# Out:
# array([254.68040083, 557.48727709, 232.15693195, 394.04688436,
#         15.4831043 , 155.42101873, 167.33719553, 903.43599226,
#        135.42695092, 874.78361919, 202.29902623, 890.17526114,
#        894.3838571 ,  10.47837206,  19.00248032,   5.46198369,
#        187.35475245, 117.45315004, 467.21193074,  14.0093925 ])

# %%
submission["hold_d"] = np.round(predict)

# %%
submission.to_csv("dacon_baseline_missinvalue_ver2.csv", index = False)
